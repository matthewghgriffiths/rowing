# %%
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import logging

import pytest

import streamlit as st
from rowing.app import select, inputs, state, plots
from rowing.analysis import files, telemetry
from rowing.utils import timeout
# Out:
# 2024-01-23 10:48:53.625 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.636 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.638 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.640 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.641 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.642 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.643 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.645 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.647 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:48:53.649 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
TIMEOUT = 10
@timeout(TIMEOUT)
def run_streamlit(main, params):
    try:
        main(params)
    except (
        st.runtime.scriptrunner.StopException,
        st.runtime.scriptrunner.RerunException,
    ):
        pass

# %%
app_GMTs = importlib.import_module("app.world_rowing.pages.1_GMTs", "..")
app_livetracker = importlib.import_module(
    "app.world_rowing.pages.2_livetracker", "..")
app_realtime = importlib.import_module(
    "app.world_rowing.pages.3_realtime", "..")
app_gpx = importlib.import_module("app.gpx", "..")
app_telemetry = importlib.import_module("app.telemetry", "..")
# Out:
# 2024-01-23 10:47:11.682 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.683 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.685 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.686 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.688 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.690 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.691 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.694 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.697 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.699 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-01-23 10:47:11.700 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
gpx_data = {
    "cam": files.read_gpx("../data/cam.gpx"),
}

# %%
app_gpx.main({"gpx_data": gpx_data})
# Out:
# 2024-01-23 10:47:13.451
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/matthew/venv/rowing39/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 0it [00:00, ?it/s]
# 2024-01-23 10:47:13.566 No runtime found, using MemoryCacheStorageManager
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-01-23 10:47:14.303 No runtime found, using MemoryCacheStorageManager
# {}
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-01-23 10:47:15.042 No runtime found, using MemoryCacheStorageManager
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# run_streamlit(app_gpx.main, {"gpx_data": gpx_data})
# Out:
# 2024-01-23 10:47:51.836 Session state does not function when running a script without `streamlit run`
# {'Make profile plots': True, 'Make all plots': True}
# INFO:telemetry:telemetry
# 2024-01-23 10:47:51.865 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 2024-01-23 10:47:52.097 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]

# %%
app_telemetry = importlib.import_module("app.telemetry", "..")
run_streamlit(
    app_telemetry.main, 
    {
        "telemetry_data": telemetry_data,
        'Make profile plots': True,
        'Make all plots': True,
    }
)
# Out:
# 2024-01-23 10:45:32.500 Session state does not function when running a script without `streamlit run`
# {'Make profile plots': True, 'Make all plots': True}
# INFO:telemetry:telemetry
# 2024-01-23 10:45:32.512 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 2024-01-23 10:45:32.608 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]

# %%
run_streamlit(app_gpx.main, {})
run_streamlit(app_telemetry.main, {})
# Out:
# INFO:telemetry:telemetry
# 2024-01-23 10:12:35.012 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 2024-01-23 10:12:35.067 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]

# %%
st.runtime.scriptrunner.get_script_run_ctx()

# %%
params = {
}
run_streamlit(app_gpx.main, params)
# Out:
# 2024-01-23 09:53:06.274
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/matthew/venv/rowing39/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 0it [00:00, ?it/s]
# 2024-01-23 09:53:06.407 No runtime found, using MemoryCacheStorageManager
# 0it [00:00, ?it/s]
# {}
# Process Process-2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matthew/src/rowing/rowing/utils.py", line 751, in handler
#     queue.put(func(*args, **kwargs))
#   File "/tmp/ipykernel_17724/1007443120.py", line 5, in run_streamlit
#     main(params)
#   File "/home/matthew/src/rowing/app/gpx.py", line 61, in main
#     all_crossing_times = pd.concat(crossing_times, names=['file'])
#   File "/home/matthew/venv/rowing39/lib/python3.9/site-packages/pandas/core/reshape/concat.py", line 372, in concat
#     op = _Concatenator(
#   File "/home/matthew/venv/rowing39/lib/python3.9/site-packages/pandas/core/reshape/concat.py", line 429, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 params = {
#       2 }
# ----> 3 run_streamlit(app_gpx.main, params)
#
# File ~/src/rowing/rowing/utils.py:766, in timeout.<locals>.decorator.<locals>.new_func(*args, **kwargs)
#     763     raise TimeoutError(
#     764         "Timed out after {} seconds".format(seconds))
#     765 else:
# --> 766     return q.get()
#
# File /usr/lib/python3.9/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File /usr/lib/python3.9/multiprocessing/connection.py:221, in _ConnectionBase.recv_bytes(self, maxlength)
#     219 if maxlength is not None and maxlength < 0:
#     220     raise ValueError("negative maxlength")
# --> 221 buf = self._recv_bytes(maxlength)
#     222 if buf is None:
#     223     self._bad_message_length()
#
# File /usr/lib/python3.9/multiprocessing/connection.py:419, in Connection._recv_bytes(self, maxsize)
#     418 def _recv_bytes(self, maxsize=None):
# --> 419     buf = self._recv(4)
#     420     size, = struct.unpack("!i", buf.getvalue())
#     421     if size == -1:
#
# File /usr/lib/python3.9/multiprocessing/connection.py:384, in Connection._recv(self, size, read)
#     382 remaining = size
#     383 while remaining > 0:
# --> 384     chunk = read(handle, remaining)
#     385     n = len(chunk)
#     386     if n == 0:
#
# KeyboardInterrupt:
